# %% [markdown]
# # Machine Learning, DNN for regression
#
# ### Description of the dataset NO2
# The dataset that we are going to use for this lesson was obtained from the StatLib repository. http://lib.stat.cmu.edu/datasets/ (NO2).
# The data are a subsample of 500 observations from a data set that originate in a study where air pollution at a road is related to traffic volume and meteorological variables, collected by the Norwegian Public Roads Administration. The response variable (column 1) consist of hourly values of the logarithm of the concentration of NO2 (particles), measured at Alnabru in Oslo, Norway, between October 2001 and August 2003. The predictor variables (columns 2 to 8) are the logarithm of the number of cars per hour, temperature $2$ meters above ground (degree C), wind speed (meters/second), the temperature difference between $25$ and $2$ meters above ground (degree C), wind direction (degrees between 0 and 360), hour of day and day number from October 1 2001. Submitted by Magne Aldrin (magne.aldrin@nr.no). [28/Jul/04] (19kbytes)
#
#
# Target variable:
# - NO2 concentration (log) [lno2]
#
# Features:
# - log of car per hour [lc]
#
# - temperature 2 meters above the ground (degree C)[t2]
#
# - wind speed (meters/seconds) [ws]
#
# - temperature difference between 25 meters and 2 meters above the ground (degree C) [td25]
#
# - wind direction (degrees between 0 and 360) [wd]
#
# - hour of day [hd] average house occupancy
#
# - day number from Oct. 1 2001 [dn]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics

# %% [markdown]
# ### ASSIGNING LABELS TO FEATURES
# We assign the labels to the corresponding columns to have a clean representation of the dataset

# %%
features = ['lc', 't2', 'ws', 'td25', 'wd', 'hd', 'dn']

# %% [markdown]
# ### CREATE THE DNN LARGE NETWORK MODEL
#
#
# <img src="images/DNN-all.png" alt="DNN Model Large" width="500"/>
#
#
# #### Create the network as indicated in the image above. All activation functions should be ReLU. Have a look at the slide for hints on the code to use.

# %%
def create_model_large():
    # create model
    model = Sequential()
    model.add(Dense(10, input_dim = X_train.shape[1], activation='relu'))
    model.add(Dense(30, activation= 'relu'))
    model.add(Dense(40, activation= 'relu'))
    model.add(Dense(1))
    #your code here	
    model.compile(optimizer= 'adam', loss = 'mean_squared_error', metrics = [metrics.mae])
    return model

# %% [markdown]
# ### CREATE THE TINY ANN MODEL
#
# #### Create an ANN with 1 layer containing 3 neurons (model tiny), alla activation functions should be ReLU.

# %%
def create_model_tiny():
    # create model
    model = Sequential()
    model.add(Dense(3, input_dim = X_train.shape[1], activation='relu'))
    #your code here	
    model.compile(optimizer= 'adam', loss = 'mean_squared_error', metrics = [metrics.mae])
    return model

# %% [markdown]
# ### CREATE THE SMALL ANN MODEL
#
# #### Create an ANN with 1 layer containing 10 neurons (model small), alla activation functions should be ReLU.

# %%
def create_model_small():
    # create model
    model = Sequential()
    model.add(Dense(10, input_dim=X_train.shape[1], activation= 'relu'))
    #your code here
    model.compile(optimizer= 'adam', loss = 'mean_squared_error', metrics = [metrics.mae])
    return model

# %% [markdown]
# ### CREATE THE MEDIUM DNN MODEL
#
# #### Create an DNN with 2 layers containing respectively 10 and 30 neurons (model medium), alla activation functions should be ReLU.

# %%
def create_model_medium():
    # create model
    model = Sequential()  
    model.add(Dense(10, input_dim=X_train.shape[1], activation= 'relu'))  
    model.add(Dense(30, activation= 'relu'))
    #your code here	
    model.compile(optimizer= 'adam', loss = 'mean_squared_error', metrics = [metrics.mae])
    return model

# %% [markdown]
# ### Evaluating the model
#
# The following functions computes the Root Mean Squared Error and the Normalized Root Mean Squared Error between the groud thruth (real) and inferred (pred) responses.

# %%
def RMSE(real, pred):
    return sqrt(mean_squared_error(real, pred))

def NRMSE(real, pred):
    return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))

# %% [markdown]
# ### Loading  the data
#
# #### Using the panda library to load data, provide a descriptive summary

# %%
# Load data
df = pd.read_csv('NO2.csv', index_col=False)

# Descriptive statistics summary
df.describe()
# Out:
#              lno2          lc          t2          ws        td25          wd  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     3.698368    6.973342    0.847400    3.056000    0.149400  143.370400
# std      0.750597    1.087166    6.524636    1.784172    1.065237   86.510213
# min      1.223780    4.127130  -18.600000    0.300000   -5.400000    2.000000
# 25%      3.213862    6.175842   -3.900000    1.675000   -0.200000   72.000000
# 50%      3.848020    7.425360    1.100000    2.800000    0.000000   97.000000
# 75%      4.216930    7.793175    4.900000    4.200000    0.600000  220.000000
# max      6.395090    8.348540   21.100000    9.900000    4.300000  359.000000
#
#                hd          dn
# count  500.000000  500.000000
# mean    12.382000  310.474000
# std      6.802693  200.977754
# min      1.000000   32.000000
# 25%      6.000000  118.750000
# 50%     12.500000  212.000000
# 75%     18.000000  513.000000
# max     24.000000  608.000000

# %% [markdown]
# ### Visualzing the relationships among the features in the data
#
# #### Compute and visualize a correlation matring among the features (using the seaborn library).

# %%
# Correlation matrix
corrmat = df.corr()

# Generate a mask for the upper triangle
matrix = np.triu(corrmat)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1)
sns.heatmap(corrmat, vmin=-1, vmax=1, center= 0, square=True, annot=True, annot_kws={'size': 8}, mask=matrix, fmt='.2g', cmap= 'coolwarm')

plt.show()

# %% [markdown]
# ### Standizing the data
#
# #### Standardize features to have 0 mean, sigma 1 and range between -1 and 1.  Do not standardize the response.

# %%
# Standardizing data
sc= MinMaxScaler(feature_range=(-1,1))

for var in features:
    if(var != 'lno2'):
        df[var] = sc.fit_transform(df[var].values.reshape(-1, 1))

# %% [markdown]
# ### Preparing the data for training, using validation set approach
#
# #### Remove labels and create the validation set.

# %%
#NumPy representation of the data frame (removing labels)
df = df.to_numpy() #df=df.values

#divide predictors from features
X = df[:, 1:8]
y = df[:, 0]

seed = 7
np.random.seed(seed)

# split dataset in 75% for traininig and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for traininig and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.30, random_state=seed)#insert your code here

# Model creation (choose between tiny, small, medium and large by using the appropriate function)
model = create_model_medium()
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 10)                80
#
#  dense_7 (Dense)             (None, 30)                330
#
# =================================================================
# Total params: 410
# Trainable params: 410
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit the DNN to the data

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 11/11 [==============================] - 0s 10ms/step - loss: 13.4196 - mean_absolute_error: 3.5449 - val_loss: 13.5155 - val_mean_absolute_error: 3.5712
# Epoch 2/150
# 11/11 [==============================] - 0s 3ms/step - loss: 13.3680 - mean_absolute_error: 3.5352 - val_loss: 13.4719 - val_mean_absolute_error: 3.5631
# Epoch 3/150
# 11/11 [==============================] - 0s 3ms/step - loss: 13.3169 - mean_absolute_error: 3.5256 - val_loss: 13.4275 - val_mean_absolute_error: 3.5548
# Epoch 4/150
# 11/11 [==============================] - 0s 3ms/step - loss: 13.2663 - mean_absolute_error: 3.5161 - val_loss: 13.3810 - val_mean_absolute_error: 3.5462
# Epoch 5/150
# 11/11 [==============================] - 0s 3ms/step - loss: 13.2127 - mean_absolute_error: 3.5061 - val_loss: 13.3339 - val_mean_absolute_error: 3.5375
# Epoch 6/150
# 11/11 [==============================] - 0s 3ms/step - loss: 13.1595 - mean_absolute_error: 3.4962 - val_loss: 13.2868 - val_mean_absolute_error: 3.5288
# Epoch 7/150
# 11/11 [==============================] - 0s 3ms/step - loss: 13.1073 - mean_absolute_error: 3.4861 - val_loss: 13.2365 - val_mean_absolute_error: 3.5196
# Epoch 8/150
# 11/11 [==============================] - 0s 3ms/step - loss: 13.0522 - mean_absolute_error: 3.4759 - val_loss: 13.1839 - val_mean_absolute_error: 3.5099
# Epoch 9/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.9978 - mean_absolute_error: 3.4657 - val_loss: 13.1276 - val_mean_absolute_error: 3.4997
# Epoch 10/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.9386 - mean_absolute_error: 3.4545 - val_loss: 13.0712 - val_mean_absolute_error: 3.4894
# Epoch 11/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.8794 - mean_absolute_error: 3.4438 - val_loss: 13.0128 - val_mean_absolute_error: 3.4788
# Epoch 12/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.8172 - mean_absolute_error: 3.4322 - val_loss: 12.9530 - val_mean_absolute_error: 3.4680
# Epoch 13/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.7543 - mean_absolute_error: 3.4206 - val_loss: 12.8877 - val_mean_absolute_error: 3.4563
# Epoch 14/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.6872 - mean_absolute_error: 3.4082 - val_loss: 12.8170 - val_mean_absolute_error: 3.4439
# Epoch 15/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.6134 - mean_absolute_error: 3.3952 - val_loss: 12.7456 - val_mean_absolute_error: 3.4316
# Epoch 16/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.5399 - mean_absolute_error: 3.3819 - val_loss: 12.6688 - val_mean_absolute_error: 3.4185
# Epoch 17/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.4618 - mean_absolute_error: 3.3679 - val_loss: 12.5898 - val_mean_absolute_error: 3.4049
# Epoch 18/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.3815 - mean_absolute_error: 3.3536 - val_loss: 12.5086 - val_mean_absolute_error: 3.3910
# Epoch 19/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.2988 - mean_absolute_error: 3.3390 - val_loss: 12.4231 - val_mean_absolute_error: 3.3764
# Epoch 20/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.2109 - mean_absolute_error: 3.3234 - val_loss: 12.3353 - val_mean_absolute_error: 3.3615
# Epoch 21/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.1200 - mean_absolute_error: 3.3075 - val_loss: 12.2425 - val_mean_absolute_error: 3.3457
# Epoch 22/150
# 11/11 [==============================] - 0s 3ms/step - loss: 12.0252 - mean_absolute_error: 3.2911 - val_loss: 12.1451 - val_mean_absolute_error: 3.3292
# Epoch 23/150
# 11/11 [==============================] - 0s 3ms/step - loss: 11.9268 - mean_absolute_error: 3.2741 - val_loss: 12.0460 - val_mean_absolute_error: 3.3124
# Epoch 24/150
# 11/11 [==============================] - 0s 3ms/step - loss: 11.8231 - mean_absolute_error: 3.2562 - val_loss: 11.9454 - val_mean_absolute_error: 3.2954
# Epoch 25/150
# 11/11 [==============================] - 0s 3ms/step - loss: 11.7113 - mean_absolute_error: 3.2375 - val_loss: 11.8438 - val_mean_absolute_error: 3.2781
# Epoch 26/150
# 11/11 [==============================] - 0s 3ms/step - loss: 11.5971 - mean_absolute_error: 3.2179 - val_loss: 11.7345 - val_mean_absolute_error: 3.2595
# Epoch 27/150
# 11/11 [==============================] - 0s 3ms/step - loss: 11.4728 - mean_absolute_error: 3.1972 - val_loss: 11.6144 - val_mean_absolute_error: 3.2395
# Epoch 28/150
# 11/11 [==============================] - 0s 3ms/step - loss: 11.3442 - mean_absolute_error: 3.1757 - val_loss: 11.4911 - val_mean_absolute_error: 3.2189
# Epoch 29/150
# 11/11 [==============================] - 0s 3ms/step - loss: 11.2124 - mean_absolute_error: 3.1537 - val_loss: 11.3612 - val_mean_absolute_error: 3.1974
# Epoch 30/150
# 11/11 [==============================] - 0s 3ms/step - loss: 11.0761 - mean_absolute_error: 3.1313 - val_loss: 11.2259 - val_mean_absolute_error: 3.1751
# Epoch 31/150
# 11/11 [==============================] - 0s 3ms/step - loss: 10.9341 - mean_absolute_error: 3.1081 - val_loss: 11.0797 - val_mean_absolute_error: 3.1511
# Epoch 32/150
# 11/11 [==============================] - 0s 3ms/step - loss: 10.7869 - mean_absolute_error: 3.0841 - val_loss: 10.9309 - val_mean_absolute_error: 3.1268
# Epoch 33/150
# 11/11 [==============================] - 0s 3ms/step - loss: 10.6404 - mean_absolute_error: 3.0605 - val_loss: 10.7831 - val_mean_absolute_error: 3.1024
# Epoch 34/150
# 11/11 [==============================] - 0s 3ms/step - loss: 10.4914 - mean_absolute_error: 3.0360 - val_loss: 10.6337 - val_mean_absolute_error: 3.0778
# Epoch 35/150
# 11/11 [==============================] - 0s 3ms/step - loss: 10.3403 - mean_absolute_error: 3.0115 - val_loss: 10.4804 - val_mean_absolute_error: 3.0525
# Epoch 36/150
# 11/11 [==============================] - 0s 3ms/step - loss: 10.1866 - mean_absolute_error: 2.9862 - val_loss: 10.3266 - val_mean_absolute_error: 3.0269
# Epoch 37/150
# 11/11 [==============================] - 0s 3ms/step - loss: 10.0323 - mean_absolute_error: 2.9607 - val_loss: 10.1714 - val_mean_absolute_error: 3.0011
# Epoch 38/150
# 11/11 [==============================] - 0s 3ms/step - loss: 9.8815 - mean_absolute_error: 2.9356 - val_loss: 10.0160 - val_mean_absolute_error: 2.9750
# Epoch 39/150
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7301 - mean_absolute_error: 2.9101 - val_loss: 9.8612 - val_mean_absolute_error: 2.9490
# Epoch 40/150
# 11/11 [==============================] - 0s 3ms/step - loss: 9.5786 - mean_absolute_error: 2.8852 - val_loss: 9.7109 - val_mean_absolute_error: 2.9234
# Epoch 41/150
# 11/11 [==============================] - 0s 3ms/step - loss: 9.4298 - mean_absolute_error: 2.8600 - val_loss: 9.5598 - val_mean_absolute_error: 2.8976
# Epoch 42/150
# 11/11 [==============================] - 0s 3ms/step - loss: 9.2814 - mean_absolute_error: 2.8350 - val_loss: 9.4029 - val_mean_absolute_error: 2.8709
# Epoch 43/150
# 11/11 [==============================] - 0s 3ms/step - loss: 9.1317 - mean_absolute_error: 2.8094 - val_loss: 9.2435 - val_mean_absolute_error: 2.8437
# Epoch 44/150
# 11/11 [==============================] - 0s 3ms/step - loss: 8.9809 - mean_absolute_error: 2.7836 - val_loss: 9.0835 - val_mean_absolute_error: 2.8165
# Epoch 45/150
# 11/11 [==============================] - 0s 3ms/step - loss: 8.8295 - mean_absolute_error: 2.7576 - val_loss: 8.9236 - val_mean_absolute_error: 2.7892
# Epoch 46/150
# 11/11 [==============================] - 0s 3ms/step - loss: 8.6778 - mean_absolute_error: 2.7316 - val_loss: 8.7652 - val_mean_absolute_error: 2.7622
# Epoch 47/150
# 11/11 [==============================] - 0s 3ms/step - loss: 8.5304 - mean_absolute_error: 2.7060 - val_loss: 8.6072 - val_mean_absolute_error: 2.7350
# Epoch 48/150
# 11/11 [==============================] - 0s 3ms/step - loss: 8.3850 - mean_absolute_error: 2.6807 - val_loss: 8.4513 - val_mean_absolute_error: 2.7078
# Epoch 49/150
# 11/11 [==============================] - 0s 3ms/step - loss: 8.2389 - mean_absolute_error: 2.6547 - val_loss: 8.2967 - val_mean_absolute_error: 2.6806
# Epoch 50/150
# 11/11 [==============================] - 0s 3ms/step - loss: 8.0919 - mean_absolute_error: 2.6292 - val_loss: 8.1419 - val_mean_absolute_error: 2.6533
# Epoch 51/150
# 11/11 [==============================] - 0s 3ms/step - loss: 7.9471 - mean_absolute_error: 2.6034 - val_loss: 7.9858 - val_mean_absolute_error: 2.6256
# Epoch 52/150
# 11/11 [==============================] - 0s 3ms/step - loss: 7.8020 - mean_absolute_error: 2.5774 - val_loss: 7.8314 - val_mean_absolute_error: 2.5980
# Epoch 53/150
# 11/11 [==============================] - 0s 3ms/step - loss: 7.6571 - mean_absolute_error: 2.5516 - val_loss: 7.6828 - val_mean_absolute_error: 2.5710
# Epoch 54/150
# 11/11 [==============================] - 0s 3ms/step - loss: 7.5175 - mean_absolute_error: 2.5262 - val_loss: 7.5345 - val_mean_absolute_error: 2.5440
# Epoch 55/150
# 11/11 [==============================] - 0s 3ms/step - loss: 7.3787 - mean_absolute_error: 2.5009 - val_loss: 7.3879 - val_mean_absolute_error: 2.5171
# Epoch 56/150
# 11/11 [==============================] - 0s 3ms/step - loss: 7.2423 - mean_absolute_error: 2.4759 - val_loss: 7.2440 - val_mean_absolute_error: 2.4906
# Epoch 57/150
# 11/11 [==============================] - 0s 3ms/step - loss: 7.1065 - mean_absolute_error: 2.4507 - val_loss: 7.1012 - val_mean_absolute_error: 2.4640
# Epoch 58/150
# 11/11 [==============================] - 0s 3ms/step - loss: 6.9728 - mean_absolute_error: 2.4257 - val_loss: 6.9596 - val_mean_absolute_error: 2.4375
# Epoch 59/150
# 11/11 [==============================] - 0s 5ms/step - loss: 6.8398 - mean_absolute_error: 2.4006 - val_loss: 6.8197 - val_mean_absolute_error: 2.4111
# Epoch 60/150
# 11/11 [==============================] - 0s 4ms/step - loss: 6.7098 - mean_absolute_error: 2.3761 - val_loss: 6.6827 - val_mean_absolute_error: 2.3852
# Epoch 61/150
# 11/11 [==============================] - 0s 3ms/step - loss: 6.5823 - mean_absolute_error: 2.3516 - val_loss: 6.5486 - val_mean_absolute_error: 2.3595
# Epoch 62/150
# 11/11 [==============================] - 0s 3ms/step - loss: 6.4603 - mean_absolute_error: 2.3281 - val_loss: 6.4136 - val_mean_absolute_error: 2.3335
# Epoch 63/150
# 11/11 [==============================] - 0s 3ms/step - loss: 6.3324 - mean_absolute_error: 2.3035 - val_loss: 6.2894 - val_mean_absolute_error: 2.3092
# Epoch 64/150
# 11/11 [==============================] - 0s 3ms/step - loss: 6.2174 - mean_absolute_error: 2.2808 - val_loss: 6.1595 - val_mean_absolute_error: 2.2838
# Epoch 65/150
# 11/11 [==============================] - 0s 3ms/step - loss: 6.0964 - mean_absolute_error: 2.2566 - val_loss: 6.0349 - val_mean_absolute_error: 2.2592
# Epoch 66/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.9800 - mean_absolute_error: 2.2336 - val_loss: 5.9141 - val_mean_absolute_error: 2.2351
# Epoch 67/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.8674 - mean_absolute_error: 2.2106 - val_loss: 5.7936 - val_mean_absolute_error: 2.2108
# Epoch 68/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.7551 - mean_absolute_error: 2.1878 - val_loss: 5.6759 - val_mean_absolute_error: 2.1868
# Epoch 69/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.6480 - mean_absolute_error: 2.1656 - val_loss: 5.5600 - val_mean_absolute_error: 2.1628
# Epoch 70/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.5392 - mean_absolute_error: 2.1431 - val_loss: 5.4492 - val_mean_absolute_error: 2.1397
# Epoch 71/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.4370 - mean_absolute_error: 2.1217 - val_loss: 5.3384 - val_mean_absolute_error: 2.1164
# Epoch 72/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.3324 - mean_absolute_error: 2.0997 - val_loss: 5.2325 - val_mean_absolute_error: 2.0937
# Epoch 73/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.2330 - mean_absolute_error: 2.0785 - val_loss: 5.1292 - val_mean_absolute_error: 2.0713
# Epoch 74/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.1352 - mean_absolute_error: 2.0575 - val_loss: 5.0269 - val_mean_absolute_error: 2.0490
# Epoch 75/150
# 11/11 [==============================] - 0s 3ms/step - loss: 5.0409 - mean_absolute_error: 2.0367 - val_loss: 4.9257 - val_mean_absolute_error: 2.0267
# Epoch 76/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.9451 - mean_absolute_error: 2.0160 - val_loss: 4.8285 - val_mean_absolute_error: 2.0051
# Epoch 77/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.8531 - mean_absolute_error: 1.9956 - val_loss: 4.7316 - val_mean_absolute_error: 1.9833
# Epoch 78/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.7618 - mean_absolute_error: 1.9752 - val_loss: 4.6376 - val_mean_absolute_error: 1.9622
# Epoch 79/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.6734 - mean_absolute_error: 1.9552 - val_loss: 4.5442 - val_mean_absolute_error: 1.9411
# Epoch 80/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.5868 - mean_absolute_error: 1.9355 - val_loss: 4.4519 - val_mean_absolute_error: 1.9201
# Epoch 81/150
# 11/11 [==============================] - 0s 5ms/step - loss: 4.5007 - mean_absolute_error: 1.9157 - val_loss: 4.3630 - val_mean_absolute_error: 1.8995
# Epoch 82/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.4166 - mean_absolute_error: 1.8963 - val_loss: 4.2759 - val_mean_absolute_error: 1.8792
# Epoch 83/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.3343 - mean_absolute_error: 1.8771 - val_loss: 4.1901 - val_mean_absolute_error: 1.8591
# Epoch 84/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.2544 - mean_absolute_error: 1.8582 - val_loss: 4.1055 - val_mean_absolute_error: 1.8390
# Epoch 85/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.1755 - mean_absolute_error: 1.8391 - val_loss: 4.0222 - val_mean_absolute_error: 1.8190
# Epoch 86/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.0971 - mean_absolute_error: 1.8205 - val_loss: 3.9417 - val_mean_absolute_error: 1.7996
# Epoch 87/150
# 11/11 [==============================] - 0s 3ms/step - loss: 4.0229 - mean_absolute_error: 1.8021 - val_loss: 3.8619 - val_mean_absolute_error: 1.7800
# Epoch 88/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.9478 - mean_absolute_error: 1.7839 - val_loss: 3.7842 - val_mean_absolute_error: 1.7608
# Epoch 89/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.8742 - mean_absolute_error: 1.7654 - val_loss: 3.7095 - val_mean_absolute_error: 1.7421
# Epoch 90/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.8034 - mean_absolute_error: 1.7476 - val_loss: 3.6355 - val_mean_absolute_error: 1.7235
# Epoch 91/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.7335 - mean_absolute_error: 1.7299 - val_loss: 3.5627 - val_mean_absolute_error: 1.7048
# Epoch 92/150
# 11/11 [==============================] - 0s 4ms/step - loss: 3.6642 - mean_absolute_error: 1.7122 - val_loss: 3.4922 - val_mean_absolute_error: 1.6865
# Epoch 93/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.5974 - mean_absolute_error: 1.6950 - val_loss: 3.4232 - val_mean_absolute_error: 1.6683
# Epoch 94/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.5323 - mean_absolute_error: 1.6780 - val_loss: 3.3546 - val_mean_absolute_error: 1.6502
# Epoch 95/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.4678 - mean_absolute_error: 1.6609 - val_loss: 3.2875 - val_mean_absolute_error: 1.6323
# Epoch 96/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.4029 - mean_absolute_error: 1.6439 - val_loss: 3.2239 - val_mean_absolute_error: 1.6150
# Epoch 97/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.3419 - mean_absolute_error: 1.6273 - val_loss: 3.1601 - val_mean_absolute_error: 1.5974
# Epoch 98/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.2812 - mean_absolute_error: 1.6111 - val_loss: 3.0976 - val_mean_absolute_error: 1.5803
# Epoch 99/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.2216 - mean_absolute_error: 1.5948 - val_loss: 3.0361 - val_mean_absolute_error: 1.5632
# Epoch 100/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.1623 - mean_absolute_error: 1.5784 - val_loss: 2.9774 - val_mean_absolute_error: 1.5466
# Epoch 101/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.1057 - mean_absolute_error: 1.5627 - val_loss: 2.9188 - val_mean_absolute_error: 1.5300
# Epoch 102/150
# 11/11 [==============================] - 0s 3ms/step - loss: 3.0495 - mean_absolute_error: 1.5469 - val_loss: 2.8621 - val_mean_absolute_error: 1.5137
# Epoch 103/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.9944 - mean_absolute_error: 1.5312 - val_loss: 2.8070 - val_mean_absolute_error: 1.4977
# Epoch 104/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.9409 - mean_absolute_error: 1.5157 - val_loss: 2.7530 - val_mean_absolute_error: 1.4818
# Epoch 105/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.8895 - mean_absolute_error: 1.5005 - val_loss: 2.6995 - val_mean_absolute_error: 1.4658
# Epoch 106/150
# 11/11 [==============================] - 0s 6ms/step - loss: 2.8371 - mean_absolute_error: 1.4853 - val_loss: 2.6483 - val_mean_absolute_error: 1.4503
# Epoch 107/150
# 11/11 [==============================] - 0s 4ms/step - loss: 2.7868 - mean_absolute_error: 1.4703 - val_loss: 2.5980 - val_mean_absolute_error: 1.4348
# Epoch 108/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.7389 - mean_absolute_error: 1.4557 - val_loss: 2.5485 - val_mean_absolute_error: 1.4196
# Epoch 109/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.6905 - mean_absolute_error: 1.4410 - val_loss: 2.4997 - val_mean_absolute_error: 1.4044
# Epoch 110/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.6432 - mean_absolute_error: 1.4263 - val_loss: 2.4523 - val_mean_absolute_error: 1.3893
# Epoch 111/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.5975 - mean_absolute_error: 1.4120 - val_loss: 2.4057 - val_mean_absolute_error: 1.3744
# Epoch 112/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.5527 - mean_absolute_error: 1.3977 - val_loss: 2.3602 - val_mean_absolute_error: 1.3597
# Epoch 113/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.5077 - mean_absolute_error: 1.3835 - val_loss: 2.3163 - val_mean_absolute_error: 1.3455
# Epoch 114/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.4654 - mean_absolute_error: 1.3700 - val_loss: 2.2729 - val_mean_absolute_error: 1.3314
# Epoch 115/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.4228 - mean_absolute_error: 1.3562 - val_loss: 2.2305 - val_mean_absolute_error: 1.3175
# Epoch 116/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.3821 - mean_absolute_error: 1.3429 - val_loss: 2.1887 - val_mean_absolute_error: 1.3036
# Epoch 117/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.3411 - mean_absolute_error: 1.3293 - val_loss: 2.1488 - val_mean_absolute_error: 1.2902
# Epoch 118/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.3015 - mean_absolute_error: 1.3163 - val_loss: 2.1097 - val_mean_absolute_error: 1.2769
# Epoch 119/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.2635 - mean_absolute_error: 1.3037 - val_loss: 2.0708 - val_mean_absolute_error: 1.2637
# Epoch 120/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.2253 - mean_absolute_error: 1.2908 - val_loss: 2.0331 - val_mean_absolute_error: 1.2507
# Epoch 121/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.1883 - mean_absolute_error: 1.2782 - val_loss: 1.9967 - val_mean_absolute_error: 1.2380
# Epoch 122/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.1520 - mean_absolute_error: 1.2658 - val_loss: 1.9604 - val_mean_absolute_error: 1.2252
# Epoch 123/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.1164 - mean_absolute_error: 1.2534 - val_loss: 1.9247 - val_mean_absolute_error: 1.2125
# Epoch 124/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0820 - mean_absolute_error: 1.2414 - val_loss: 1.8902 - val_mean_absolute_error: 1.2001
# Epoch 125/150
# 11/11 [==============================] - 0s 3ms/step - loss: 2.0473 - mean_absolute_error: 1.2293 - val_loss: 1.8567 - val_mean_absolute_error: 1.1879
# Epoch 126/150
# 11/11 [==============================] - 0s 5ms/step - loss: 2.0146 - mean_absolute_error: 1.2177 - val_loss: 1.8235 - val_mean_absolute_error: 1.1757
# Epoch 127/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.9817 - mean_absolute_error: 1.2060 - val_loss: 1.7909 - val_mean_absolute_error: 1.1636
# Epoch 128/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.9489 - mean_absolute_error: 1.1946 - val_loss: 1.7597 - val_mean_absolute_error: 1.1518
# Epoch 129/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.9183 - mean_absolute_error: 1.1834 - val_loss: 1.7287 - val_mean_absolute_error: 1.1402
# Epoch 130/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8872 - mean_absolute_error: 1.1723 - val_loss: 1.6990 - val_mean_absolute_error: 1.1289
# Epoch 131/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8575 - mean_absolute_error: 1.1613 - val_loss: 1.6694 - val_mean_absolute_error: 1.1175
# Epoch 132/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.8281 - mean_absolute_error: 1.1504 - val_loss: 1.6406 - val_mean_absolute_error: 1.1063
# Epoch 133/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7993 - mean_absolute_error: 1.1397 - val_loss: 1.6123 - val_mean_absolute_error: 1.0952
# Epoch 134/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7709 - mean_absolute_error: 1.1287 - val_loss: 1.5849 - val_mean_absolute_error: 1.0843
# Epoch 135/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7436 - mean_absolute_error: 1.1183 - val_loss: 1.5578 - val_mean_absolute_error: 1.0733
# Epoch 136/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.7165 - mean_absolute_error: 1.1079 - val_loss: 1.5314 - val_mean_absolute_error: 1.0625
# Epoch 137/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6895 - mean_absolute_error: 1.0976 - val_loss: 1.5061 - val_mean_absolute_error: 1.0519
# Epoch 138/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6642 - mean_absolute_error: 1.0875 - val_loss: 1.4811 - val_mean_absolute_error: 1.0415
# Epoch 139/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6390 - mean_absolute_error: 1.0775 - val_loss: 1.4562 - val_mean_absolute_error: 1.0310
# Epoch 140/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.6141 - mean_absolute_error: 1.0676 - val_loss: 1.4322 - val_mean_absolute_error: 1.0207
# Epoch 141/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5896 - mean_absolute_error: 1.0576 - val_loss: 1.4091 - val_mean_absolute_error: 1.0108
# Epoch 142/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5656 - mean_absolute_error: 1.0480 - val_loss: 1.3865 - val_mean_absolute_error: 1.0010
# Epoch 143/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5429 - mean_absolute_error: 1.0385 - val_loss: 1.3643 - val_mean_absolute_error: 0.9913
# Epoch 144/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.5197 - mean_absolute_error: 1.0290 - val_loss: 1.3428 - val_mean_absolute_error: 0.9817
# Epoch 145/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4979 - mean_absolute_error: 1.0200 - val_loss: 1.3214 - val_mean_absolute_error: 0.9722
# Epoch 146/150
# 11/11 [==============================] - 0s 5ms/step - loss: 1.4760 - mean_absolute_error: 1.0108 - val_loss: 1.3003 - val_mean_absolute_error: 0.9626
# Epoch 147/150
# 11/11 [==============================] - 0s 4ms/step - loss: 1.4546 - mean_absolute_error: 1.0018 - val_loss: 1.2800 - val_mean_absolute_error: 0.9533
# Epoch 148/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4339 - mean_absolute_error: 0.9930 - val_loss: 1.2601 - val_mean_absolute_error: 0.9440
# Epoch 149/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.4134 - mean_absolute_error: 0.9842 - val_loss: 1.2409 - val_mean_absolute_error: 0.9352
# Epoch 150/150
# 11/11 [==============================] - 0s 3ms/step - loss: 1.3935 - mean_absolute_error: 0.9757 - val_loss: 1.2218 - val_mean_absolute_error: 0.9262

# %% [markdown]
# ### Evaluate accuracy and loss of your model. This is how your plots should look like:
# <table><tr>
# <td> <img src="images/accuracy.png" style="width: 500px;"/> </td>
# <td> <img src="images/loss.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### Now evaluate the predictions of your model in terms of RMSE and NRMSE. You should obtain plots like these:
# <table><tr>
# <td> <img src="images/inference.png" style="width: 500px;"/> </td>
# <td> <img src="images/inference_diff.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Prediction
pred = model.predict(X_test).reshape(1,-1)[0]

rmse = RMSE(y_test, pred)
nrmse = NRMSE(y_test, pred)


print("rmse : ",rmse,"  nrmse : ",nrmse)
# Out:
# 4/4 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_16527/2558052338.py in <module>
#       2 pred = model.predict(X_test).reshape(1,-1)[0]
#       3
# ----> 4 rmse = RMSE(y_test, pred)
#       5 nrmse = NRMSE(y_test, pred)
#       6
#
# /tmp/ipykernel_16527/98545407.py in RMSE(real, pred)
#       1 def RMSE(real, pred):
# ----> 2     return sqrt(mean_squared_error(real, pred))
#       3
#       4 def NRMSE(real, pred):
#       5     return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))
#
# ~/miniconda3/envs/ai-lab/lib/python3.7/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     437     """
#     438     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 439         y_true, y_pred, multioutput
#     440     )
#     441     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~/miniconda3/envs/ai-lab/lib/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~/miniconda3/envs/ai-lab/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
# --> 334             % [int(l) for l in lengths]
#     335         )
#     336
#
# ValueError: Found input variables with inconsistent numbers of samples: [125, 375]

# %%
my_x=np.arange(0,len(X_test[:,0]),1)

fig = plt.figure(figsize=(20,10))
plt.scatter(my_x, y_test, label='Real', color='blue', marker='o')
plt.scatter(my_x, pred, label='Inference', color='red', marker='s')
plt.title(f'Inference of log(NO2)  rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('log(NO2)')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
my_d = abs(y_test-pred)

plt.bar(my_x,my_d)
plt.title(f'Inference of log(NO2) -- absolute difference between inference and ground truth rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('absolute value of difference in inference [log(NO2)]')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.show()
